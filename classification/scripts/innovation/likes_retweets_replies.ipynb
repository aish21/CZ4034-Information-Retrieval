# %%
# !pip install chardet
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import chardet
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.data.path.append("/usr/share/nltk_data")

import pandas as pd
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Conv1D, MaxPooling1D, MaxPooling1D, GlobalMaxPooling1D, Dropout, Bidirectional
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt
import re
import tensorflow as tf
import numpy as np
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adamax 
from keras import regularizers
import ast
from keras.layers import Dense, Embedding, LSTM, Dropout, Bidirectional
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.optimizers import Adamax
from keras import regularizers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam 
from matplotlib import pyplot as plt
import chardet
from tensorflow.keras.initializers import he_uniform
# Out:
# Requirement already satisfied: chardet in /Users/wenxiu/miniconda3/envs/info-ret/lib/python3.9/site-packages (5.1.0)
# [nltk_data] Downloading package punkt to /Users/wenxiu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/wenxiu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/wenxiu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/wenxiu/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
data = pd.read_csv('/Users/wenxiu/Documents/GitHub/CZ4034-Information-Retrieval-Grp-28/data/processed/combined_vader_textblob_classified_data.csv', encoding="ISO-8859-1")
data
# Out:
# /var/folders/n8/3f_jyqrd5r97gbpz42mt5mn00000gn/T/ipykernel_78744/2696913460.py:1: DtypeWarning: Columns (1,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/Users/wenxiu/Documents/GitHub/CZ4034-Information-Retrieval-Grp-28/data/processed/combined_vader_textblob_classified_data.csv', encoding="ISO-8859-1")
#              username verified  followersCount  \
# 0              G_F758    False             343
# 1        DeVinSimmons    False             421
# 2             cozzboz    False             117
# 3      Fantastic_4ork    False             486
# 4       jordan_sebas2    False             487
# ...               ...      ...             ...
# 79545         Abfun77    False             382
# 79546        Vivern96    False               7
# 79547   EllieCupcakes    False             263
# 79548      Pinknotess    False               0
# 79549  TheAshenHollow    False            2405
#
#                                               rawContent             date  \
# 0      Hogwarts Legacy Flight the Good Flight (SILVER...  18/2/2023 12:47
# 1      Oh and how smooth getting on and off the broom...   16/2/2023 5:27
# 2      Playing endless hours of #HogwartsLegacy got m...  16/2/2023 14:34
# 3      Hey #AvalancheSoftware how about that #photomo...  15/2/2023 19:24
# 4      Hogwarts Legacy Flight the Good Flight (SILVER...  15/2/2023 19:57
# ...                                                  ...              ...
# 79545  Video of ELDEN RING: All Quests in Order + Mis...   22/2/2023 0:17
# 79546  Red Wolf of Radagon RL1 NoHit #ELDEN_RING #ELD...  16/6/2022 14:29
# 79547  Fanart of Miruku with her Apostle (Slim) and M...   3/3/2023 21:01
# 79548  This comic is definitely worth reading! Come c...   19/3/2023 3:42
# 79549  New video is out now! ÃÂ°ÃÂÃÂÃÂ Who the...   11/6/2022 2:42
#
#       replyCount retweetCount  likeCount  \
# 0              0            0        1.0
# 1              0            0        0.0
# 2              0            0        0.0
# 3              0            0        3.0
# 4              0            0        0.0
# ...          ...          ...        ...
# 79545          0            7       79.0
# 79546          0            0        1.0
# 79547          1            7       32.0
# 79548          0            0        0.0
# 79549          0            5       19.0
#
#                                                      url  \
# 0      https://twitter.com/G_F758/status/162692648616...
# 1      https://twitter.com/DeVinSimmons/status/162609...
# 2      https://twitter.com/cozzboz/status/16262284309...
# 3      https://twitter.com/Fantastic_4ork/status/1625...
# 4      https://twitter.com/jordan_sebas2/status/16259...
# ...                                                  ...
# 79545  https://twitter.com/Abfun77/status/16281871857...
# 79546  https://twitter.com/Vivern96/status/1537442134...
# 79547  https://twitter.com/EllieCupcakes/status/16317...
# 79548  https://twitter.com/Pinknotess/status/16372984...
# 79549  https://twitter.com/TheAshenHollow/status/1535...
#
#                                                 hashtags  ...  \
# 0      ['PlayStationTrophy', 'PS5Share', 'HogwartsLeg...  ...
# 1                                     ['HogwartsLegacy']  ...
# 2                                     ['HogwartsLegacy']  ...
# 3      ['AvalancheSoftware', 'photomode', 'hogwartsle...  ...
# 4      ['PlayStationTrophy', 'PS5Share', 'HogwartsLeg...  ...
# ...                                                  ...  ...
# 79545  ['ELDENRING', 'ELDEN_RING', 'guide', 'gaming',...  ...
# 79546      ['ELDEN_RING', 'ELDENRING', 'gaming', 'game']  ...
# 79547                      ['EldenRing', 'EldenRingArt']  ...
# 79548        ['EldenRing', 'illusrtationart', 'Romance']  ...
# 79549                        ['ELDEN_RING', 'EldenRing']  ...
#
#                                 vader_preprocessing_text  vader_neg vader_neu  \
# 0      hogwarts legacy flight the good flight (silver...      0.000     0.674
# 1      oh and how smooth getting on and off the broom...      0.000     1.000
# 2      playing endless hours of  got me in the mood f...      0.000     0.904
# 3      hey  how about that  for  ? adegaa$?a*adegaaa ...      0.000     1.000
# 4      hogwarts legacy flight the good flight (silver...      0.000     0.530
# ...                                                  ...        ...       ...
# 79545  video of elden ring: all quests in order + mis...      0.000     1.000
# 79546                 red wolf of radagon rl1 nohit           0.000     1.000
# 79547  fanart of miruku with her apostle (slim) and m...      0.000     1.000
# 79548  this comic is definitely worth reading! come c...      0.000     0.607
# 79549  new video is out now! adegaaa who the fudge is...      0.106     0.894
#
#       vader_pos  vader_comp  class  TextBlob_Subjectivity  TextBlob_Polarity  \
# 0         0.326      0.4404      1               0.600000           0.700000
# 1         0.000      0.0000      0               0.500000           0.400000
# 2         0.096      0.2023      1               0.575000          -0.062500
# 3         0.000      0.0000      0               0.000000           0.000000
# 4         0.470      0.7964      1               0.533333           0.266667
# ...         ...         ...    ...                    ...                ...
# 79545     0.000      0.0000      0               0.767857           0.142857
# 79546     0.000      0.0000      0               0.000000           0.000000
# 79547     0.000      0.0000      0               0.000000           0.000000
# 79548     0.393      0.6351      1               0.300000           0.359375
# 79549     0.000     -0.3595     -1               0.454545           0.170455
#
#        TextBlob_Analysis  final_class
# 0                      1          0.0
# 1                      1          0.0
# 2                     -1          0.0
# 3                      0          0.0
# 4                      1          0.0
# ...                  ...          ...
# 79545                  1          0.0
# 79546                  0          0.0
# 79547                  0          0.0
# 79548                  1          1.0
# 79549                  1         -1.0
#
# [79550 rows x 23 columns]

# %%
data['processed'] = data['processed'].apply(ast.literal_eval)
data['use_col'] = data['processed'].apply(lambda x: ' '.join(x))

# %%
data['retweetCount'] = data['retweetCount'].fillna(0)
data['retweetCount'] = data['retweetCount'].apply(lambda x: x if type(x)== float or type(x)== int else 0)
data['retweetCount'] = data['retweetCount'].astype(np.float32)

data['replyCount'] = data['replyCount'].fillna(0)
data['replyCount'] = data['replyCount'].apply(lambda x: x if type(x)== float or type(x)== int else 0)
data['replyCount'] = data['replyCount'].astype(np.float32)

data['likeCount'] = data['likeCount'].fillna(0)
data['likeCount'] = data['likeCount'].apply(lambda x: x if type(x)== float or type(x)== int else 0)
data['likeCount'] = data['likeCount'].astype(np.float32)

# %%
type(data['retweetCount'][79547])
# Out:
# numpy.float32

# %%
data['likeCount'].value_counts()
# Out:
# 0.0       32423
# 1.0       16172
# 2.0        7233
# 3.0        4115
# 4.0        2622
#           ...
# 1588.0        1
# 2197.0        1
# 560.0         1
# 6627.0        1
# 926.0         1
# Name: likeCount, Length: 1377, dtype: int64

# %%
data['use_col']
# Out:
# 0        hogwarts legacy flight the good flight silver ...
# 1            oh and how smooth get on and off the broom be
# 2        play endless hours of get me in the mood for s...
# 3                        hey how about that for d d 1 2aai
# 4        hogwarts legacy flight the good flight silver ...
#                                ...
# 79545    video of elder ring all quest in order disable...
# 79546     red wolf of dragon rl1 not https t co avnntrkqdo
# 79547    apart of miruku with her apostle slim and miru...
# 79548    this comic be definitely worth read come check...
# 79549    new video be out now d who the judge be this m...
# Name: use_col, Length: 79550, dtype: object

# %%
X = data[['likeCount', 'retweetCount', 'replyCount', 'use_col']]
labels = data['final_class']

labels = tf.keras.utils.to_categorical(labels, 3, dtype="float32")
tokenizer = Tokenizer(num_words=30000, split=' ')
tokenizer.fit_on_texts(data['use_col'].values)
maxlen=200

X_train, X_test, Y_train, Y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

X1_train = tokenizer.texts_to_sequences(X_train['use_col'].values)
X1_train = pad_sequences(X1_train, padding='post', maxlen=maxlen)

X1_test = tokenizer.texts_to_sequences(X_test['use_col'].values)
X1_test = pad_sequences(X1_test, padding='post', maxlen=maxlen)

# %%
X2_train = X_train[['likeCount', 'retweetCount', 'replyCount']].values
X2_test = X_test[['likeCount', 'retweetCount', 'replyCount']].values

# %%
print(X1_train.shape)
print(X1_test.shape)
print(X2_train.shape)
print(X2_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (63640, 200)
# (15910, 200)
# (63640, 3)
# (15910, 3)
# (63640, 3)
# (15910, 3)

# %%
X1_train
# Out:
# array([[   6,  213,  374, ...,    0,    0,    0],
#        [ 961, 1370,  215, ...,    0,    0,    0],
#        [  13,  350,   14, ...,    0,    0,    0],
#        ...,
#        [   4,   94,  176, ...,    0,    0,    0],
#        [  46,   57,  137, ...,    0,    0,    0],
#        [  46,   57,  385, ...,    0,    0,    0]], dtype=int32)

# %%
X2_test = np.asarray(X2_test).astype(np.float32)

# %%
from keras.layers import Concatenate
from keras.models import Model, Sequential
from keras.layers import Dense, Input
from keras.callbacks import EarlyStopping

model1_in = Input(shape=(maxlen,))

embedding_layer = Embedding(input_dim=30000, output_dim=40, input_length=X1_train.shape[1])(model1_in)
dropout_1 = Dropout(0.7)(embedding_layer)
bilstm_1 = Bidirectional(LSTM(units=128, return_sequences=True, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))(embedding_layer)
dropout_2 = Dropout(0.7)(bilstm_1)
model1_out = Bidirectional(LSTM(units=64, return_sequences=False, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))(dropout_2)

model2_in = Input(shape=(3,))
model2_out = Dense(10, activation='relu')(model2_in)

concat_layer = Concatenate()([model1_out, model2_out])
dense_layer_3 = Dense(10, activation='relu')(concat_layer)
output = Dense(3, activation='softmax')(dense_layer_3)
model = Model(inputs=[model1_in, model2_in], outputs=output)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, mode='min', restore_best_weights=True)

# %%
# from keras.callbacks import EarlyStopping

# model_dropout = Sequential()

# model_dropout.add(Embedding(input_dim=30000, output_dim=40, input_length=X.shape[1]))
# model_dropout.add(Dropout(0.7))
# model_dropout.add(Bidirectional(LSTM(units=128, return_sequences=True, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01))))
# model_dropout.add(Dropout(0.7))
# model_dropout.add(Bidirectional(LSTM(units=64, return_sequences=False, kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01))))
# model_dropout.add(Dense(3, activation='softmax'))

# optimizer = Adamax(lr=0.01)
# model_dropout.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

# early_stopping = EarlyStopping(monitor='val_loss', patience=3, mode='min', restore_best_weights=True)

# print(model_dropout.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 103, 40)           1200000
#
#  dropout (Dropout)           (None, 103, 40)           0
#
#  bidirectional (Bidirectiona  (None, 103, 256)         173056
#  l)
#
#  dropout_1 (Dropout)         (None, 103, 256)          0
#
#  bidirectional_1 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dense (Dense)               (None, 3)                 387
#
# =================================================================
# Total params: 1,537,795
# Trainable params: 1,537,795
# Non-trainable params: 0
# _________________________________________________________________
# None
# /Users/wenxiu/miniconda3/envs/info-ret/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adamax.py:99: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(x=[X1_train, X2_train], y=[Y_train,Y_train], epochs = 100, batch_size=256, validation_data=([X1_test, X2_test] , [Y_test, Y_test]), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 2023-04-05 15:01:02.710697: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 249/249 [==============================] - 284s 1s/step - loss: 13.3681 - categorical_accuracy: 0.5234 - val_loss: 4.2414 - val_categorical_accuracy: 0.6212
# Epoch 2/100
# 249/249 [==============================] - 285s 1s/step - loss: 1.8727 - categorical_accuracy: 0.6913 - val_loss: 1.0054 - val_categorical_accuracy: 0.7163
# Epoch 3/100
# 249/249 [==============================] - 290s 1s/step - loss: 0.7674 - categorical_accuracy: 0.8019 - val_loss: 0.7104 - val_categorical_accuracy: 0.7542
# Epoch 4/100
# 249/249 [==============================] - 288s 1s/step - loss: 0.6078 - categorical_accuracy: 0.8478 - val_loss: 0.6512 - val_categorical_accuracy: 0.8155
# Epoch 5/100
# 249/249 [==============================] - 289s 1s/step - loss: 0.5979 - categorical_accuracy: 0.8638 - val_loss: 0.5799 - val_categorical_accuracy: 0.8243
# Epoch 6/100
# 249/249 [==============================] - 286s 1s/step - loss: 0.7560 - categorical_accuracy: 0.7357 - val_loss: 1.3128 - val_categorical_accuracy: 0.4245
# Epoch 7/100
# 249/249 [==============================] - 288s 1s/step - loss: 1.0874 - categorical_accuracy: 0.6050 - val_loss: 0.7802 - val_categorical_accuracy: 0.7556
# Epoch 8/100
# 249/249 [==============================] - 287s 1s/step - loss: 0.5660 - categorical_accuracy: 0.8486 - val_loss: 0.8170 - val_categorical_accuracy: 0.8155

# %%
from sklearn.metrics import f1_score, classification_report

# Get the predicted probabilities on the test set
y_pred_prob = model.predict([X1_test, X2_test])

# Convert the predicted probabilities to integer class labels
y_pred = y_pred_prob.argmax(axis=-1)

# Convert the one-hot encoded labels to integers
y_true = Y_test.argmax(axis=-1)
report = classification_report(y_true, y_pred, target_names=['-1','0','1'])
print(report)
# Out:
# 498/498 [==============================] - 40s 79ms/step
#               precision    recall  f1-score   support
#
#           -1       0.88      0.81      0.85      6017
#            0       0.77      0.86      0.81      5511
#            1       0.83      0.80      0.82      4382
#
#     accuracy                           0.82     15910
#    macro avg       0.83      0.82      0.82     15910
# weighted avg       0.83      0.82      0.82     15910

# %%
# Plotting the accuracies
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
# plt.savefig('./overall_acc.png')

# %%
# Plotting the losses
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='upper left')
# plt.savefig('./overall_loss.png')

# %%
from sklearn.metrics import f1_score

# Get the predicted probabilities on the test set
y_pred_prob = model_dropout.predict(X_test)

# Convert the predicted probabilities to integer class labels
y_pred = y_pred_prob.argmax(axis=-1)

# Convert the one-hot encoded labels to integers
y_true = Y_test.argmax(axis=-1)

# Calculate the F1 score
f1 = f1_score(y_true, y_pred, average='macro')
print("F1 score:", f1)
# Out:
# 498/498 [==============================] - 25s 49ms/step
# F1 score: 0.8705780978036478
